# %%
# !MPLBACKEND=agg python train.py \
  --depth 4 \
  --width 4 \
  --epochs 20 \
  --train_batch_size 128 \
  --lr 0.001
# Out:
# _________________________________________________
#
# 20250922 21:07:43 train.py main() running.
# True
# checkpoint: check_default
# data_path: ../data
# depth: 4
# epochs: 20
# lr: 0.001
# lr_factor: 0.1
# lr_schedule: [100, 150]
# model: recur_resnet
# model_path: None
# shuffle: True
# optimizer: adam
# output: output_default
# quick_test: False
# save_json: False
# save_period: 20
# test_batch_size: 500
# test_iterations: None
# test_mode: default
# train_batch_size: 128
# train_log: train_log.txt
# train_mode: default
# val_period: 20
# warmup_period: 5
# width: 4
# test_maze_size: 13
# train_maze_size: 9
# logging done in output_default.
# ...
# Traceback (most recent call last):
#   File "/shared/home/lrlab/LoopWorks/Team3/hb/Loopedmodel_research/Capstone-2025-1-team3-main/R-ResNet/train.py", line 292, in <module>
#     main()
#   File "/shared/home/lrlab/LoopWorks/Team3/hb/Loopedmodel_research/Capstone-2025-1-team3-main/R-ResNet/train.py", line 84, in main
# ...
