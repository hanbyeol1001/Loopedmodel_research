# %%
# !MPLBACKEND=agg python main.py \
--model ut_act \
--depth 4 \
--width 4 \
--epochs 50 \
--train_batch_size 128 \
--test_batch_size 128 \
--lr 0.001 \
--val_period 10 \
--train_maze_size 9 \
--test_maze_size 9 \
--quick_test \
--train_mode act
# Out:
# _________________________________________________
#
# 20250923 14:04:52 main.py main() running.
# True
# checkpoint: check_default
# data_path: ../data
# depth: 4
# epochs: 50
# lr: 0.001
# lr_factor: 0.1
# lr_schedule: [100, 150]
# model: ut_act
# model_path: None
# shuffle: True
# optimizer: adam
# output: output_default
# quick_test: True
# save_json: False
# save_period: 50
# test_batch_size: 128
# test_iterations: None
# test_mode: default
# train_batch_size: 128
# train_log: train_log.txt
# train_mode: act
# val_period: 10
# warmup_period: 5
# width: 4
# test_maze_size: 9
# train_maze_size: 9
# logging done in output_default.
# dataset size 확인-------------------------------------------------
# Inputs tensor shape from trainloader: torch.Size([128, 3, 24, 24])
# Targets tensor shape from trainloader: torch.Size([128, 24, 24])
# 확인 끝-----------------------------------------------------------
# This ut_act has 1.279 million parameters.
# Training will start at epoch 0.
# ...
